# %%
import os
import numpy as np
import pandas as pd
import swifter
from sklearn.model_selection import train_test_split
import utils
import catboost

# %%
DATA_PATH = "./data"

# %%
train, test = utils.load_data_csv(DATA_PATH, utils.SIMPLE_FEATURE_COLUMNS)
# Out:
# /root/anaconda3/envs/idao_cb/lib/python3.6/site-packages/numpy/lib/arraysetops.py:522: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
train.columns
# Out:
# Index(['ncl[0]', 'ncl[1]', 'ncl[2]', 'ncl[3]', 'avg_cs[0]', 'avg_cs[1]',
#        'avg_cs[2]', 'avg_cs[3]', 'ndof', 'MatchedHit_TYPE[0]',
#        'MatchedHit_TYPE[1]', 'MatchedHit_TYPE[2]', 'MatchedHit_TYPE[3]',
#        'MatchedHit_X[0]', 'MatchedHit_X[1]', 'MatchedHit_X[2]',
#        'MatchedHit_X[3]', 'MatchedHit_Y[0]', 'MatchedHit_Y[1]',
#        'MatchedHit_Y[2]', 'MatchedHit_Y[3]', 'MatchedHit_Z[0]',
#        'MatchedHit_Z[1]', 'MatchedHit_Z[2]', 'MatchedHit_Z[3]',
#        'MatchedHit_DX[0]', 'MatchedHit_DX[1]', 'MatchedHit_DX[2]',
#        'MatchedHit_DX[3]', 'MatchedHit_DY[0]', 'MatchedHit_DY[1]',
#        'MatchedHit_DY[2]', 'MatchedHit_DY[3]', 'MatchedHit_DZ[0]',
#        'MatchedHit_DZ[1]', 'MatchedHit_DZ[2]', 'MatchedHit_DZ[3]',
#        'MatchedHit_T[0]', 'MatchedHit_T[1]', 'MatchedHit_T[2]',
#        'MatchedHit_T[3]', 'MatchedHit_DT[0]', 'MatchedHit_DT[1]',
#        'MatchedHit_DT[2]', 'MatchedHit_DT[3]', 'Lextra_X[0]', 'Lextra_X[1]',
#        'Lextra_X[2]', 'Lextra_X[3]', 'Lextra_Y[0]', 'Lextra_Y[1]',
#        'Lextra_Y[2]', 'Lextra_Y[3]', 'NShared', 'Mextra_DX2[0]',
#        'Mextra_DX2[1]', 'Mextra_DX2[2]', 'Mextra_DX2[3]', 'Mextra_DY2[0]',
#        'Mextra_DY2[1]', 'Mextra_DY2[2]', 'Mextra_DY2[3]', 'FOI_hits_N', 'PT',
#        'P', 'label', 'weight'],
#       dtype='object')

# %%
func = utils.find_closest_hit_per_station

# %%
# dt_train = pd.read_hdf('closest_hits_features.train.filled.p1000.hdf', 'key')
# dt_test  = pd.read_hdf('closest_hits_features.test.filled.p1000.hdf', 'key')

dt_train = pd.read_hdf('closest_hits_features.train.filled.m9999.v1.hdf', 'key')
dt_test  = pd.read_hdf('closest_hits_features.test.filled.m9999.v1.hdf', 'key')

# %%
dt_train.columns = [func.__name__ + '_' + str(c) if str(c).isnumeric() else c for c in dt_train.columns]
dt_test.columns  = [func.__name__ + '_' + str(c) if str(c).isnumeric() else c for c in dt_test.columns]

# %%
dt_train.head()
# Out:
#    find_closest_hit_per_station_0  find_closest_hit_per_station_1  \
# 0                      387.780334                     1326.855347
# 1                      663.537231                       69.836296
# 2                       20.678513                        8.433522
# 3                       18.436918                      296.695587
# 4                       52.339714                       27.757668
#
#    find_closest_hit_per_station_2  find_closest_hit_per_station_3  \
# 0                      863.780151                    34716.441406
# 1                     9215.460938                    59107.925781
# 2                     1119.618042                      125.378754
# 3                      451.847870                       92.326012
# 4                      400.102539                       21.006199
#
#    find_closest_hit_per_station_4  find_closest_hit_per_station_5  \
# 0                      433.571838                      502.340942
# 1                     1052.492310                     1204.408569
# 2                     1307.314087                     1588.550781
# 3                      213.281387                      270.486450
# 4                     3240.037354                     3816.010254
#
#    find_closest_hit_per_station_6  find_closest_hit_per_station_7  \
# 0                      519.029846                      467.281677
# 1                     1368.801270                     1568.593140
# 2                    10996.653320                    12932.460938
# 3                      303.733368                      284.749146
# 4                     4264.797852                     4543.026367
#
#    find_closest_hit_per_station_8  find_closest_hit_per_station_9  ...  \
# 0                             3.0                             2.0  ...
# 1                             9.0                            10.0  ...
# 2                            10.0                             3.0  ...
# 3                             6.0                             4.0  ...
# 4                             6.0                             6.0  ...
#
#    find_closest_hit_per_station_38  find_closest_hit_per_station_39  \
# 0                        88.609863                       186.323486
# 1                        95.997192                       243.121216
# 2                        33.460693                        11.197266
# 3                       -21.256714                        -9.608643
# 4                        20.002563                        -4.583252
#
#    find_closest_hit_per_station_40  find_closest_hit_per_station_41  \
# 0                        20.822388                        22.412964
# 1                        32.442139                        34.704590
# 2                       -12.044800                      -137.772888
# 3                       -48.595123                        16.446472
# 4                       -32.543945                        61.773865
#
#    find_closest_hit_per_station_42  find_closest_hit_per_station_43  \
# 0                        22.782227                        21.616699
# 1                        36.997314                        39.605469
# 2                      -104.864929                      -113.720978
# 3                        17.427948                        16.874512
# 4                        65.305420                        67.401978
#
#    FOI_hits_N[0]  FOI_hits_N[1]  FOI_hits_N[2]  FOI_hits_N[3]
# 0              2              1              2              1
# 1              1              1              1              1
# 2              2              5              1              1
# 3              2              1              1              1
# 4              3              1              1              1
#
# [5 rows x 48 columns]

# %%
train = pd.concat([train, dt_train], axis=1, copy=False)
test = pd.concat([test, dt_test], axis=1, copy=False)

# %%
del test

# %% [markdown]
# ## Новые признаки

# %%
NA_VALUE = -9999.0

# %%
def fillna(df):
    """
    Пропуски только в 2 и 3 колонках
    """
    
    for axis in 'XYZ':
        cols = ['MatchedHit_{}[{}]'.format(axis, i) for i in range(4)]
        mask = np.isclose(df.loc[:, cols[2]], NA_VALUE)
        mask = mask & ~np.isclose(df.loc[:, cols[3]], NA_VALUE)
        
        df.loc[mask, cols[2]] = df.loc[mask, [cols[1], cols[3]]].mean(axis=1)
    return df

# %%
# train, test = map(fillna, [train, test])

# %%
train = fillna(train)

# %% [markdown]
# ### Вычесть среднее из MatchedHit_Z

# %%
matched_hit_z_cols = train.columns.str.startswith("MatchedHit_Z")
mask = np.isclose(train.loc[:, matched_hit_z_cols], NA_VALUE).any(axis=0)
matched_hit_z_mean = train.loc[~mask, matched_hit_z_cols].mean(axis=0)
matched_hit_z_mean
# Out:
# MatchedHit_Z[0]    15167.8215
# MatchedHit_Z[1]    16374.1045
# MatchedHit_Z[2]    17567.8400
# MatchedHit_Z[3]    18776.8770
# dtype: float64

# %%
matched_hit_z_cols = train.columns[train.columns.str.startswith("MatchedHit_Z")]
matched_hit_z_mean = pd.Series([15270, 16470, 17670, 18870], index=matched_hit_z_cols)
matched_hit_z_mean
# Out:
# MatchedHit_Z[0]    15270
# MatchedHit_Z[1]    16470
# MatchedHit_Z[2]    17670
# MatchedHit_Z[3]    18870
# dtype: int64

# %%
def make_unbiased_z(df):
    for i in range(4):
        distance = np.zeros(df.shape[0])
    
        col = f"MatchedHit_Z[{i}]"
        mask = np.isclose(df.loc[:, col], NA_VALUE)
        distance[~mask] = df.loc[~mask, col] - matched_hit_z_mean[col]
        distance[mask] = NA_VALUE
    
        df[col] = distance
        
#         df[f"MatchedHit_Z[{i}]_sign"] = np.sign(df[col]).astype(np.int8)
    return df

# %%
# train, test = map(make_unbiased_z, [train, test])

# %%
train = make_unbiased_z(train)

# %%
train.loc[:, train.columns.str.startswith("MatchedHit_Z")].head()
# Out:
#    MatchedHit_Z[0]  MatchedHit_Z[1]  MatchedHit_Z[2]  MatchedHit_Z[3]
# 0         -146.955         -142.367         -149.174         -140.676
# 1          -57.402          -49.424          -55.146          -45.570
# 2           47.953           52.060          -71.700          -63.648
# 3          -68.590          -64.445          -71.700          -63.648
# 4          -64.511          -60.047          -66.979          -58.605

# %% [markdown]
# ### Расстояние до центра (+)

# %%
def compute_polar_distances_matched_hit(df):
    for i in range(4):
        cols = [f"MatchedHit_X[{i}]", f"MatchedHit_Y[{i}]"]
        mask = np.isclose(df.loc[:, cols], NA_VALUE).any(axis=1)
    
        name = f"MatchedHit_R[{i}]"
        df[name] = NA_VALUE
        df.loc[~mask, name] = np.log(1.0 + np.power(df.loc[~mask, cols], 2).sum(axis=1))
        
        name = f"MatchedHit_A[{i}]"
        df[name] = NA_VALUE
        df.loc[~mask, name] = np.arctan2(df.loc[~mask, cols[1]], df.loc[~mask, cols[0]])

    # намеренное переупорядочивание признаков
    cols  = df.columns[df.columns.str.startswith("MatchedHit_R")].tolist()
    cols += df.columns[df.columns.str.startswith("MatchedHit_A")].tolist()
    cols  = df.columns[:-len(cols)].tolist() + cols
    df = df[cols]

    return df

# %%
# train, test = map(compute_polar_distances_matched_hit, [train, test])

# %%
train = compute_polar_distances_matched_hit(train)

# %%
train.loc[:, train.columns.str.startswith("MatchedHit_R")].head()
# Out:
#    MatchedHit_R[0]  MatchedHit_R[1]  MatchedHit_R[2]  MatchedHit_R[3]
# 0        16.023317        16.206292        16.332808        16.583070
# 1        15.647796        15.811899        15.934739        16.044511
# 2        14.788550        14.971064        15.147750        15.280270
# 3        14.899596        15.022741        15.147750        15.280270
# 4        14.962988        15.139525        15.316049        15.449411

# %%
train.loc[:, train.columns.str.startswith("MatchedHit_A")].head()
# Out:
#    MatchedHit_A[0]  MatchedHit_A[1]  MatchedHit_A[2]  MatchedHit_A[3]
# 0         2.668808         2.676832         2.672886         2.701153
# 1         1.270437         1.251195         1.280089         1.319231
# 2        -2.944427        -2.947037        -3.027307        -3.028216
# 3        -3.030048        -3.028084        -3.027307        -3.028216
# 4         2.582489         2.590782         2.601329         2.600883

# %% [markdown]
# ### Расстояние между Lextra и MatchedHit (+)

# %%
def distance_dist_lextra_matched(df):
    distance_counts = np.zeros(df.shape[0], dtype=int)
    
    distance_se = np.zeros(df.shape[0])
    distance_ae = np.zeros(df.shape[0])
    
    for i in range(4):
        distance = np.zeros(df.shape[0])

        cols = [f"MatchedHit_X[{i}]", f"MatchedHit_Y[{i}]", f"Lextra_X[{i}]", f"Lextra_Y[{i}]"]
        mask = np.isclose(df.loc[:, cols], NA_VALUE).any(axis=1)

        mse = df.loc[~mask, cols[:2]].values - df.loc[~mask, cols[2:]].values
        mse = np.power(mse, 2.0).sum(axis=1)
        
        mae = df.loc[~mask, cols[:2]].values - df.loc[~mask, cols[2:]].values
        mae = np.abs(mae).max(axis=1)

        distance[~mask] = np.log(1.0 + mse)
        distance[mask] = NA_VALUE
        
        distance_se[~mask] += mse
        distance_ae[~mask] = np.maximum(distance_ae[~mask], mae)
        distance_counts[~mask] += 1

        df[f"distance_LextraMatchedHit[{i}]"] = distance

    distance_se /= distance_counts
    df[f"distance_LextraMatchedHit_SE"] = distance_se
    df[f"distance_LextraMatchedHit_AE"] = distance_ae

    return df

# %%
# train, test = map(distance_dist_lextra_matched, [train, test])

# %%
train = distance_dist_lextra_matched(train)

# %%
train.loc[:, train.columns.str.startswith("distance_LextraMatchedHit")].head()
# Out:
#    distance_LextraMatchedHit[0]  distance_LextraMatchedHit[1]  \
# 0                      6.712163                      7.512178
# 1                      7.448349                      7.150894
# 2                      7.192176                      7.376499
# 3                      5.449827                      6.342438
# 4                      8.099670                      8.254467
#
#    distance_LextraMatchedHit[2]  distance_LextraMatchedHit[3]  \
# 0                      7.232589                     10.468368
# 1                      9.267218                     11.013328
# 2                      9.402387                      9.477220
# 3                      6.628810                      5.935092
# 4                      8.448039                      8.426182
#
#    distance_LextraMatchedHit_SE  distance_LextraMatchedHit_AE
# 0                   9804.277406                     186.32360
# 1                  18562.759955                     243.12120
# 2                   7024.772423                     113.72097
# 3                    482.888433                      21.25670
# 4                   4091.272154                      67.40200

# %% [markdown]
# ### Дельты и отношения для радиусов (+)

# %%
def ratio_radius_matched_hit(df):
    for i, j in zip([0, 1, 2, 3], [1, 2, 3, 0]):
        col_i = f"MatchedHit_R[{i}]"
        col_j = f"MatchedHit_R[{j}]"
        mask = np.isclose(df.loc[:, [col_i, col_j]], NA_VALUE).any(axis=1)

        name = f"MatchedHit_R[{j}/{i}]_delta"
        name_abs = name + '_abs'
        df[name] = df[name_abs] = NA_VALUE
        
        df.loc[~mask, name] = df.loc[~mask, col_j] - df.loc[~mask, col_i]
        df.loc[~mask, name_abs] = np.abs(df.loc[~mask, name])
        
        name = f"MatchedHit_R[{j}/{i}]_frac"
        df[name] = NA_VALUE
        df.loc[~mask, name] = df.loc[~mask, col_j] / df.loc[~mask, col_i]
    return df

# %%
# train, test = map(ratio_radius_matched_hit, [train, test])

# %%
train = ratio_radius_matched_hit(train)

# %%
cols = filter(lambda s: s.startswith("MatchedHit_R") and ("_delta" in s or "_frac" in s), train.columns)
train.loc[:, cols].head()
# Out:
#    MatchedHit_R[1/0]_delta  MatchedHit_R[1/0]_delta_abs  \
# 0                 0.182975                     0.182975
# 1                 0.164103                     0.164103
# 2                 0.182513                     0.182513
# 3                 0.123146                     0.123146
# 4                 0.176537                     0.176537
#
#    MatchedHit_R[1/0]_frac  MatchedHit_R[2/1]_delta  \
# 0                1.011419                 0.126516
# 1                1.010487                 0.122840
# 2                1.012342                 0.176687
# 3                1.008265                 0.125009
# 4                1.011798                 0.176523
#
#    MatchedHit_R[2/1]_delta_abs  MatchedHit_R[2/1]_frac  \
# 0                     0.126516                1.007807
# 1                     0.122840                1.007769
# 2                     0.176687                1.011802
# 3                     0.125009                1.008321
# 4                     0.176523                1.011660
#
#    MatchedHit_R[3/2]_delta  MatchedHit_R[3/2]_delta_abs  \
# 0                 0.250262                     0.250262
# 1                 0.109772                     0.109772
# 2                 0.132520                     0.132520
# 3                 0.132520                     0.132520
# 4                 0.133362                     0.133362
#
#    MatchedHit_R[3/2]_frac  MatchedHit_R[0/3]_delta  \
# 0                1.015323                -0.559754
# 1                1.006889                -0.396714
# 2                1.008748                -0.491720
# 3                1.008748                -0.380674
# 4                1.008707                -0.486422
#
#    MatchedHit_R[0/3]_delta_abs  MatchedHit_R[0/3]_frac
# 0                     0.559754                0.966245
# 1                     0.396714                0.975274
# 2                     0.491720                0.967820
# 3                     0.380674                0.975087
# 4                     0.486422                0.968515

# %% [markdown]
# ### Отношение дисперсий

# %%
def ratio_mextra_matched(df):    
    for i in range(4):
        cols = [f"MatchedHit_DX[{i}]", f"MatchedHit_DY[{i}]", f"Mextra_DX2[{i}]", f"Mextra_DY2[{i}]"]
        mask = np.isclose(df.loc[:, cols], NA_VALUE).any(axis=1)

        tmpX = df.loc[~mask, cols[::2]]
        tmpY = df.loc[~mask, cols[1::2]]
        
        ratio = tmpX.iloc[:, 0] / np.sqrt(tmpX.iloc[:, 1]) + \
                tmpY.iloc[:, 0] / np.sqrt(tmpY.iloc[:, 1])

        name = f"ratio_MextraMatchedHit[{i}]"
        df[name] = NA_VALUE
        df.loc[~mask, name] = ratio

    return df

# %%
# train, test = map(ratio_mextra_matched, [train, test])

# %%
train = ratio_mextra_matched(train)

# %%
train.loc[:, train.columns.str.startswith("ratio_MextraMatchedHit")].head()
# Out:
#    ratio_MextraMatchedHit[0]  ratio_MextraMatchedHit[1]  \
# 0                   8.287385                   5.293275
# 1                  18.965682                  12.044753
# 2                   6.001871                   3.893571
# 3                  12.649516                   8.039806
# 4                   5.487896                   3.481615
#
#    ratio_MextraMatchedHit[2]  ratio_MextraMatchedHit[3]
# 0                   5.687804                   4.349901
# 1                  13.049134                  32.661490
# 2                   4.204257                   3.224819
# 3                   8.694506                   6.719570
# 4                   3.740265                   2.870688

# %% [markdown]
# ### Еще один момент

# %%
def momentum(df):
    mask = np.isclose(df.loc[:, ['P', 'PT']], NA_VALUE).any(axis=1)
    df['PO'] = NA_VALUE
    df.loc[~mask, 'PO'] = np.power(df.loc[~mask, 'P'], 2.0) - np.power(df.loc[~mask, 'PT'], 2.0)
    return df

# %%
# train, test = map(momentum, [train, test])

# %%
train = momentum(train)

# %%
train.loc[:, ['P', 'PT', 'PO']].head()
# Out:
#               P           PT            PO
# 0  12646.817591  1764.925899  1.568270e+08
# 1  28556.630027  4511.281266  7.951295e+08
# 2  17491.702634  1062.550086  3.048306e+08
# 3  37192.868559  4991.074825  1.358399e+09
# 4  16688.746174  1347.704888  2.766979e+08

# %% [markdown]
# ### Отношение NShared к FOI_hits_N

# %%
def nshared_foihits(df):
    df.loc[:, "frac_NShared_FOI_hits_N"] = df.loc[:, "NShared"] / df.loc[:, "FOI_hits_N"] 
    df.loc[:, "frac_NShared_FOI_hits_N"] = df.loc[:, "frac_NShared_FOI_hits_N"].fillna(-1)
    return df

# %%
# train, test = map(nshared_foihits, [train, test])

# %%
train = nshared_foihits(train)

# %%
train.loc[:, ["NShared", "FOI_hits_N", "frac_NShared_FOI_hits_N"]].head()
# Out:
#    NShared  FOI_hits_N  frac_NShared_FOI_hits_N
# 0        0           6                     0.00
# 1        1           4                     0.25
# 2        0           9                     0.00
# 3        0           5                     0.00
# 4        0           6                     0.00

# %% [markdown]
# ### Число объектов в кластерах

# %%
def cluster_size(df):
    for i in range(4):
        name = f'cl_size[{i}]'
        df[name] = NA_VALUE
        
        cols = [f'ncl[{i}]', f'avg_cs[{i}]']
        mask = np.isclose(df.loc[:, cols], NA_VALUE).any(axis=1)
        df.loc[~mask, name] = df.loc[~mask, cols[0]] * df.loc[~mask, cols[1]]
    return df

# %%
# train, test = map(cluster_size, [train, test])

# %%
train = cluster_size(train)

# %%
train.loc[:, train.columns.str.startswith('cl_size')].head()
# Out:
#    cl_size[0]  cl_size[1]  cl_size[2]  cl_size[3]
# 0   94.000000   49.000001   14.999999   17.000000
# 1  253.000000   53.000002   15.000000   32.000002
# 2  293.000000   51.000001   12.999999   13.000001
# 3  227.000002   67.999997   25.000000   26.000000
# 4   33.000001   43.000001    9.000000   14.000000

# %% [markdown]
# ### Удаляем лишние колонки

# %%
def drop_columns(df):
    mask = df.columns.str.startswith('MatchedHit_X') | \
           df.columns.str.startswith('MatchedHit_Y') | \
           df.columns.str.startswith('Lextra_X') | \
           df.columns.str.startswith('Lextra_Y') | \
           df.columns.str.startswith('FOI_hits_N[') | \
           df.columns.str.startswith('MatchedHit_D') | \
           df.columns.str.startswith('Mextra_D') | \
           df.columns.str.startswith("ndof")
    df[df.columns[mask]] = -1
    return df

# %%
# train, test = map(drop_columns, [train, test])

# %%
train = drop_columns(train)

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# I know this is incorrect. See it as a low-hanging fruit to beat the baseline. Catboost affirmatively [refused](https://github.com/catboost/catboost/pull/399) to support negative weights. At the same time, its evaluation is [extremly fast](https://catboost.ai/news/best-in-class-inference-and-a-ton-of-speedups), so we are using it as the timing benchmark for Track 2. Feel free to use a patched version with disabled negative weights check.

# %%
features = list(filter(lambda s: s not in utils.TRAIN_COLUMNS, train.columns))
features
# Out:
# ['ncl[0]',
#  'ncl[1]',
#  'ncl[2]',
#  'ncl[3]',
#  'avg_cs[0]',
#  'avg_cs[1]',
#  'avg_cs[2]',
#  'avg_cs[3]',
#  'ndof',
#  'MatchedHit_TYPE[0]',
#  'MatchedHit_TYPE[1]',
#  'MatchedHit_TYPE[2]',
#  'MatchedHit_TYPE[3]',
#  'MatchedHit_X[0]',
#  'MatchedHit_X[1]',
#  'MatchedHit_X[2]',
#  'MatchedHit_X[3]',
#  'MatchedHit_Y[0]',
#  'MatchedHit_Y[1]',
#  'MatchedHit_Y[2]',
#  'MatchedHit_Y[3]',
#  'MatchedHit_Z[0]',
#  'MatchedHit_Z[1]',
#  'MatchedHit_Z[2]',
#  'MatchedHit_Z[3]',
#  'MatchedHit_DX[0]',
#  'MatchedHit_DX[1]',
#  'MatchedHit_DX[2]',
#  'MatchedHit_DX[3]',
#  'MatchedHit_DY[0]',
#  'MatchedHit_DY[1]',
#  'MatchedHit_DY[2]',
#  'MatchedHit_DY[3]',
#  'MatchedHit_DZ[0]',
#  'MatchedHit_DZ[1]',
#  'MatchedHit_DZ[2]',
#  'MatchedHit_DZ[3]',
#  'MatchedHit_T[0]',
#  'MatchedHit_T[1]',
#  'MatchedHit_T[2]',
#  'MatchedHit_T[3]',
#  'MatchedHit_DT[0]',
#  'MatchedHit_DT[1]',
#  'MatchedHit_DT[2]',
#  'MatchedHit_DT[3]',
#  'Lextra_X[0]',
#  'Lextra_X[1]',
#  'Lextra_X[2]',
#  'Lextra_X[3]',
#  'Lextra_Y[0]',
#  'Lextra_Y[1]',
#  'Lextra_Y[2]',
#  'Lextra_Y[3]',
#  'NShared',
#  'Mextra_DX2[0]',
#  'Mextra_DX2[1]',
#  'Mextra_DX2[2]',
#  'Mextra_DX2[3]',
#  'Mextra_DY2[0]',
#  'Mextra_DY2[1]',
#  'Mextra_DY2[2]',
#  'Mextra_DY2[3]',
#  'FOI_hits_N',
#  'PT',
#  'P',
#  'find_closest_hit_per_station_0',
#  'find_closest_hit_per_station_1',
#  'find_closest_hit_per_station_2',
#  'find_closest_hit_per_station_3',
#  'find_closest_hit_per_station_4',
#  'find_closest_hit_per_station_5',
#  'find_closest_hit_per_station_6',
#  'find_closest_hit_per_station_7',
#  'find_closest_hit_per_station_8',
#  'find_closest_hit_per_station_9',
#  'find_closest_hit_per_station_10',
#  'find_closest_hit_per_station_11',
#  'find_closest_hit_per_station_12',
#  'find_closest_hit_per_station_13',
#  'find_closest_hit_per_station_14',
#  'find_closest_hit_per_station_15',
#  'find_closest_hit_per_station_16',
#  'find_closest_hit_per_station_17',
#  'find_closest_hit_per_station_18',
#  'find_closest_hit_per_station_19',
#  'find_closest_hit_per_station_20',
#  'find_closest_hit_per_station_21',
#  'find_closest_hit_per_station_22',
#  'find_closest_hit_per_station_23',
#  'find_closest_hit_per_station_24',
#  'find_closest_hit_per_station_25',
#  'find_closest_hit_per_station_26',
#  'find_closest_hit_per_station_27',
#  'find_closest_hit_per_station_28',
#  'find_closest_hit_per_station_29',
#  'find_closest_hit_per_station_30',
#  'find_closest_hit_per_station_31',
#  'find_closest_hit_per_station_32',
#  'find_closest_hit_per_station_33',
#  'find_closest_hit_per_station_34',
#  'find_closest_hit_per_station_35',
#  'find_closest_hit_per_station_36',
#  'find_closest_hit_per_station_37',
#  'find_closest_hit_per_station_38',
#  'find_closest_hit_per_station_39',
#  'find_closest_hit_per_station_40',
#  'find_closest_hit_per_station_41',
#  'find_closest_hit_per_station_42',
#  'find_closest_hit_per_station_43',
#  'FOI_hits_N[0]',
#  'FOI_hits_N[1]',
#  'FOI_hits_N[2]',
#  'FOI_hits_N[3]',
#  'MatchedHit_R[0]',
#  'MatchedHit_R[1]',
#  'MatchedHit_R[2]',
#  'MatchedHit_R[3]',
#  'MatchedHit_A[0]',
#  'MatchedHit_A[1]',
#  'MatchedHit_A[2]',
#  'MatchedHit_A[3]',
#  'distance_LextraMatchedHit[0]',
#  'distance_LextraMatchedHit[1]',
#  'distance_LextraMatchedHit[2]',
#  'distance_LextraMatchedHit[3]',
#  'distance_LextraMatchedHit_SE',
#  'distance_LextraMatchedHit_AE',
#  'MatchedHit_R[1/0]_delta',
#  'MatchedHit_R[1/0]_delta_abs',
#  'MatchedHit_R[1/0]_frac',
#  'MatchedHit_R[2/1]_delta',
#  'MatchedHit_R[2/1]_delta_abs',
#  'MatchedHit_R[2/1]_frac',
#  'MatchedHit_R[3/2]_delta',
#  'MatchedHit_R[3/2]_delta_abs',
#  'MatchedHit_R[3/2]_frac',
#  'MatchedHit_R[0/3]_delta',
#  'MatchedHit_R[0/3]_delta_abs',
#  'MatchedHit_R[0/3]_frac',
#  'ratio_MextraMatchedHit[0]',
#  'ratio_MextraMatchedHit[1]',
#  'ratio_MextraMatchedHit[2]',
#  'ratio_MextraMatchedHit[3]',
#  'PO',
#  'frac_NShared_FOI_hits_N',
#  'cl_size[0]',
#  'cl_size[1]',
#  'cl_size[2]',
#  'cl_size[3]']

# %%
model = catboost.CatBoostClassifier(iterations=1600, max_depth=5, thread_count=16,
                                    verbose=False, task_type='GPU')

# %%
model.fit(train.loc[:, features].values, train.loc[:, 'label'].values,
          sample_weight=np.abs(train.loc[:, 'weight'].values))

# %%
sorted(zip(features, model.feature_importances_), key=lambda f: f[-1], reverse=True)
# Out:
# [('PT', 20.005063017269674),
#  ('distance_LextraMatchedHit_SE', 8.641282550771075),
#  ('frac_NShared_FOI_hits_N', 5.35150116583821),
#  ('NShared', 5.012510716820441),
#  ('distance_LextraMatchedHit_AE', 4.424564387485871),
#  ('P', 3.2383987454419825),
#  ('MatchedHit_R[1]', 3.146545265496897),
#  ('MatchedHit_R[3]', 2.8033238008210914),
#  ('MatchedHit_R[1/0]_delta_abs', 2.327856929834401),
#  ('find_closest_hit_per_station_0', 2.1488033270223554),
#  ('cl_size[0]', 2.1336304793403147),
#  ('Mextra_DX2[3]', 2.095704915964742),
#  ('MatchedHit_R[2/1]_delta_abs', 1.764251783248225),
#  ('find_closest_hit_per_station_1', 1.732917455999717),
#  ('PO', 1.5455008139267037),
#  ('MatchedHit_R[0]', 1.3793395149519379),
#  ('distance_LextraMatchedHit[0]', 1.259651160080909),
#  ('ncl[2]', 1.1009211624541864),
#  ('MatchedHit_R[2]', 0.8968542872524176),
#  ('ncl[3]', 0.8432140345180003),
#  ('MatchedHit_R[1/0]_delta', 0.8380218761544442),
#  ('find_closest_hit_per_station_24', 0.8166965135354167),
#  ('MatchedHit_R[3/2]_delta_abs', 0.798567035302161),
#  ('find_closest_hit_per_station_23', 0.7339248380190166),
#  ('find_closest_hit_per_station_18', 0.7141508757184176),
#  ('ncl[1]', 0.6980912475821051),
#  ('MatchedHit_DX[2]', 0.6650116916111332),
#  ('Mextra_DY2[3]', 0.6636544580123047),
#  ('find_closest_hit_per_station_19', 0.6355876244515264),
#  ('find_closest_hit_per_station_25', 0.5854530426374255),
#  ('distance_LextraMatchedHit[1]', 0.5699412023963398),
#  ('find_closest_hit_per_station_36', 0.5432021382385048),
#  ('distance_LextraMatchedHit[3]', 0.5393860255423308),
#  ('MatchedHit_TYPE[1]', 0.5239363466924332),
#  ('MatchedHit_TYPE[2]', 0.5208848239609207),
#  ('ratio_MextraMatchedHit[0]', 0.5147572451687005),
#  ('ncl[0]', 0.4891604842359617),
#  ('find_closest_hit_per_station_29', 0.472137908023824),
#  ('Mextra_DX2[2]', 0.43320249918353726),
#  ('MatchedHit_DT[0]', 0.43147119611113327),
#  ('find_closest_hit_per_station_28', 0.4227746556752178),
#  ('avg_cs[1]', 0.41791218097303506),
#  ('find_closest_hit_per_station_34', 0.4039532868614034),
#  ('find_closest_hit_per_station_4', 0.39680297330132064),
#  ('find_closest_hit_per_station_3', 0.39443096560991175),
#  ('MatchedHit_DX[3]', 0.36109215924826665),
#  ('find_closest_hit_per_station_22', 0.3554064978534525),
#  ('ratio_MextraMatchedHit[3]', 0.34851230556891144),
#  ('MatchedHit_DZ[2]', 0.32458073609500937),
#  ('find_closest_hit_per_station_7', 0.32009596784086863),
#  ('MatchedHit_Y[1]', 0.3119517639330359),
#  ('avg_cs[2]', 0.30928733533605424),
#  ('MatchedHit_DY[1]', 0.29263299785899455),
#  ('find_closest_hit_per_station_32', 0.27443693399146196),
#  ('find_closest_hit_per_station_39', 0.2516517227096401),
#  ('find_closest_hit_per_station_33', 0.2506814364952544),
#  ('distance_LextraMatchedHit[2]', 0.24994705645777662),
#  ('ratio_MextraMatchedHit[1]', 0.2496019442449932),
#  ('avg_cs[3]', 0.24353074554107168),
#  ('MatchedHit_R[0/3]_delta_abs', 0.2426906211690736),
#  ('find_closest_hit_per_station_35', 0.22812365755705907),
#  ('MatchedHit_T[3]', 0.2263153448440094),
#  ('MatchedHit_DZ[0]', 0.2248133825734898),
#  ('find_closest_hit_per_station_31', 0.2216361654152889),
#  ('find_closest_hit_per_station_30', 0.21680368171813114),
#  ('MatchedHit_DT[1]', 0.2088710273912064),
#  ('Mextra_DY2[1]', 0.20594474508734179),
#  ('Mextra_DX2[0]', 0.20458753456887147),
#  ('MatchedHit_Y[0]', 0.2038947241845437),
#  ('MatchedHit_X[3]', 0.19662215446042286),
#  ('ratio_MextraMatchedHit[2]', 0.19338175515955888),
#  ('find_closest_hit_per_station_27', 0.19175776302266834),
#  ('find_closest_hit_per_station_12', 0.18706486893461863),
#  ('MatchedHit_Y[3]', 0.18670782648636608),
#  ('Lextra_X[0]', 0.1858629004856858),
#  ('cl_size[1]', 0.1798341464473683),
#  ('MatchedHit_DY[0]', 0.17803951263590626),
#  ('MatchedHit_Z[0]', 0.1767232484121496),
#  ('MatchedHit_R[3/2]_frac', 0.1681238071659834),
#  ('find_closest_hit_per_station_2', 0.16701429440926235),
#  ('FOI_hits_N', 0.16265881101773236),
#  ('find_closest_hit_per_station_38', 0.15846185139835514),
#  ('find_closest_hit_per_station_41', 0.1562882190390703),
#  ('find_closest_hit_per_station_37', 0.15395822723596228),
#  ('MatchedHit_R[1/0]_frac', 0.15273147206869306),
#  ('MatchedHit_T[2]', 0.15158489565316322),
#  ('MatchedHit_T[0]', 0.145671479378709),
#  ('MatchedHit_DZ[3]', 0.14371172923065273),
#  ('cl_size[3]', 0.1406357438540797),
#  ('MatchedHit_Y[2]', 0.13857987353147902),
#  ('MatchedHit_X[0]', 0.1321332269746522),
#  ('find_closest_hit_per_station_26', 0.12800137904090328),
#  ('MatchedHit_Z[1]', 0.12502787910365623),
#  ('MatchedHit_DX[0]', 0.12486310047654754),
#  ('Lextra_X[2]', 0.12438133809550131),
#  ('find_closest_hit_per_station_40', 0.12271602380944724),
#  ('Mextra_DY2[2]', 0.1203164117152343),
#  ('MatchedHit_T[1]', 0.117877766849244),
#  ('MatchedHit_X[2]', 0.11572422956194557),
#  ('cl_size[2]', 0.11456434142275938),
#  ('Lextra_X[3]', 0.11379888031177716),
#  ('find_closest_hit_per_station_5', 0.10979434315094395),
#  ('FOI_hits_N[0]', 0.10887166112824281),
#  ('MatchedHit_R[3/2]_delta', 0.10228049489938551),
#  ('MatchedHit_Z[2]', 0.1018960148036415),
#  ('find_closest_hit_per_station_6', 0.09232121803212023),
#  ('find_closest_hit_per_station_13', 0.0912911845455826),
#  ('MatchedHit_DZ[1]', 0.08981531739683758),
#  ('MatchedHit_X[1]', 0.08899624258505887),
#  ('MatchedHit_DY[3]', 0.08720602325159332),
#  ('MatchedHit_TYPE[0]', 0.08506393861612277),
#  ('Mextra_DX2[1]', 0.08345796872806825),
#  ('MatchedHit_Z[3]', 0.08021051328450839),
#  ('Mextra_DY2[0]', 0.07908017038359597),
#  ('Lextra_Y[3]', 0.07848070133421686),
#  ('Lextra_Y[0]', 0.07714275381406968),
#  ('find_closest_hit_per_station_14', 0.07507978793289168),
#  ('Lextra_Y[2]', 0.07295011386242903),
#  ('Lextra_Y[1]', 0.07261601422200066),
#  ('avg_cs[0]', 0.07189933946905057),
#  ('find_closest_hit_per_station_42', 0.07189158722554512),
#  ('find_closest_hit_per_station_15', 0.0687521789016922),
#  ('MatchedHit_R[2/1]_frac', 0.06803671065632425),
#  ('Lextra_X[1]', 0.06761878348143431),
#  ('MatchedHit_R[0/3]_frac', 0.06616840068375493),
#  ('MatchedHit_R[0/3]_delta', 0.05765872587977226),
#  ('find_closest_hit_per_station_16', 0.054987963227351735),
#  ('MatchedHit_A[2]', 0.05429616545620188),
#  ('find_closest_hit_per_station_43', 0.05333989679989578),
#  ('MatchedHit_A[0]', 0.0517172801659673),
#  ('MatchedHit_TYPE[3]', 0.04859553356932034),
#  ('FOI_hits_N[2]', 0.04635061811876772),
#  ('find_closest_hit_per_station_21', 0.04555682890827509),
#  ('find_closest_hit_per_station_8', 0.04048831811358282),
#  ('MatchedHit_DT[3]', 0.03806734132131766),
#  ('find_closest_hit_per_station_9', 0.03744200504021446),
#  ('MatchedHit_DT[2]', 0.033192775650984274),
#  ('MatchedHit_A[3]', 0.0317236024623789),
#  ('MatchedHit_A[1]', 0.028655163971021434),
#  ('find_closest_hit_per_station_20', 0.028442562944904708),
#  ('MatchedHit_R[2/1]_delta', 0.022412762998939163),
#  ('FOI_hits_N[3]', 0.019357710310358146),
#  ('find_closest_hit_per_station_11', 0.01622978359027262),
#  ('find_closest_hit_per_station_10', 0.015377259810486288),
#  ('MatchedHit_DY[2]', 0.013274369198219085),
#  ('find_closest_hit_per_station_17', 0.012806100287977474),
#  ('FOI_hits_N[1]', 0.0022474751736373515),
#  ('ndof', 0.0),
#  ('MatchedHit_DX[1]', 0.0)]

# %%
model.save_model("track_2_model-1600-5-vb.cbm")
